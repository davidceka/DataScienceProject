# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('dataset/finalePython.csv')

# %%
# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['iataorigid'], kde=False)
plt.title('Distribution of flights by origin', fontsize = 20)
plt.xlabel('Range of Origin ids')
plt.ylabel('Count')

# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['iatadestid'], kde=False)
plt.title('Distribution of flights by destination', fontsize = 20)
plt.xlabel('Range of destination ids')
plt.ylabel('Count')

# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['tailnumid'], kde=False)
plt.title('Distribution of flights by flight number', fontsize = 20)
plt.xlabel('Range of flight number ids')
plt.ylabel('Count')

# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['statecodeorigid'], kde=False)
plt.title('Distribution of flights by state orig', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')

# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['statecodedestid'], kde=False)
plt.title('Distribution of flights by state dest', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')

# Diabetes_012
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['uniquecarrierid'], kde=False)
plt.title('Distribution of flights by carrier', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')

# %% [markdown]
# ### Analisi dei ritardi

# %%
ritardi=data[(data['carrierdelay']>0) | (data['weatherdelay']>0) | (data['nasdelay']>0) | (data['securitydelay']>0)]
ritardi.head()

# %% [markdown]
# ### Analisi per compagnia(carrier)

# %%
plt.figure(figsize=(40,100))
plt.subplot(11, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['uniquecarrierid'], kde=True)
plt.title('Distribution of flights by carrier', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')

# %%
labels = ['0', '1']
size = ritardi['uniquecarrierid'].value_counts()
colors = ['pink', 'lightblue']
explode = [0, 0.1]

plt.figure(figsize=(18,18))
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Sex of people with Diabetes', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(40,20))
sns.heatmap(ritardi.corr(), cmap = 'Blues', annot = True, annot_kws={"fontsize": 16})
plt.title('Heatmap', fontsize = 20)
plt.show()

# %%
# carrier delay vs carrier id

plt.figure(figsize=(18,7))
sns.distplot(data.loc[data['uniquecarrierid']==0]['carrierdelay'],kde=False)
sns.distplot(data.loc[data['uniquecarrierid']==1]['carrierdelay'],kde=False)
plt.title('Carrier delay vs carrier id',fontsize=20)
plt.show()
